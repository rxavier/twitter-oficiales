# %%
import pandas as pd

import base

# %%
PATH = "data.csv"
USERS_DATA = ["SCPresidenciauy", "oppuruguay", "1500Opp", "MRREE_Uruguay", "MGAPUruguay",
              "MDN_Uruguay", "Mvotma_Uruguay", "midesuy", "MIEM_Uruguay",
              "MI_UNICOM", "mef_Uruguay", "Uruguay_Natural", "MEC_Uruguay",
              "MSPUruguay", "MTSSuy", "mtopuy", "ASSEcomunica", "ANEP_Uruguay",
              "Udelaruy"]
USERS_PLOT = ["SCPresidenciauy", "oppuruguay", "1500Opp", "MRREE_Uruguay", "MGAPUruguay",
              "MDN_Uruguay", "Mvotma_Uruguay", "midesuy", "MIEM_Uruguay",
              "MI_UNICOM", "mef_Uruguay", "Uruguay_Natural", "MEC_Uruguay",
              "MSPUruguay", "MTSSuy", "mtopuy", "ASSEcomunica", "ANEP_Uruguay",
              "Udelaruy"]

# %%
prev_data = pd.read_csv(PATH, sep=" ").sort_values(["User", "Date"])
full_data = base.get_data(USERS_DATA, data=prev_data)

# %%
plot, data = base.mungle_plot(full_data, users=USERS_PLOT, aggregation="7D",
                              end="2019-11-18")
plot
# Out:
# <ggplot: (-9223372036551320397)>
